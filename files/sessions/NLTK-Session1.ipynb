# %%
import nltk

from nltk.book import *
 text3
# Out:
#   File "<ipython-input-1-ccbb05d518b6>", line 4
#     text3
#     ^
# IndentationError: unexpected indent

# %%
import nltk

# %%
nltk.download ('all')
# Out:
# [nltk_data] Downloading collection u'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/researcher/nltk_data...
# ...

# %%
nltk.download ('all')
# Out:
# [nltk_data] Downloading collection u'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/researcher/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/researcher/nltk_data...
# ...

# %%
from nltk.book import *

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
len(text2)
# Out:
# 141576

# %%
set(text2)
# Out:
# {u'succour',
#  u'four',
#  u'woods',
#  u'hanging',
#  u'woody',
#  u'conjure',
#  u'looking',
#  u'eligible',
#  u'scold',
#  u'unsuitableness',
#  u'meadows',
#  u'stipulate',
#  u'leisurely',
#  u'bringing',
#  u'disturb',
#  u'internally',
#  u'hostess',
#  u'mohrs',
#  u'persisted',
#  u'Does',
#  u'succession',
#  u'tired',
#  u'cordially',
#  u'pulse',
#  u'elegant',
#  u'second',
#  u'sooth',
#  u'shrugging',
#  u'abundantly',
#  u'errors',
#  u'forgetting',
#  u'contributed',
#  u'fingers',
#  u'increasing',
#  u'exclamations',
#  u'hero',
#  u'leaning',
#  u'Truth',
#  u'here',
#  u'china',
#  u'hers',
#  u'natured',
#  u'substance',
#  u'unwillingness',
#  u'pretensions',
#  u'reports',
#  u'NOT',
#  u'NOW',
#  u'projection',
#  u'sweetest',
#  u'explained',
#  u'Three',
#  u'summons',
#  u'brought',
#  u'forbore',
#  u'cherishing',
#  u'spoke',
#  u'impartiality',
#  u'music',
#  u'therefore',
#  u'strike',
#  u'females',
#  u'successful',
#  u'brings',
#  u'hurt',
# ...

# %%
len(set(text2))
# Out:
# 6833

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text1.similar("monstrous")
# Out:
# imperial subtly impalpable pitiable curious abundant perilous
# trustworthy untoward singular lamentable few determined maddens
# horrible tyrannical lazy mystifying christian exasperate

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text2.common_contexts(["monstrous","very"])
# Out:
# a_pretty is_pretty a_lucky am_glad be_glad

# %%
import numpy
# %matplotlib inline
text1.dispersion_plot(['whale'])

# %%
text4
# Out:
# <Text: Inaugural Address Corpus>

# %%
text4.dispersion_plot(['citizens','democracy','freedom','duties','America'])

# %%
string='user'
if string=='user':
    print 'fixed!'
# Out:
# fixed!

# %%
def welcome (name):
    print 'Welcome %s' % name

# %%
welcome('Toby')
# Out:
# Welcome Toby

# %%
len (text2)/len(set(text2))
# Out:
# 20

# %%
def lexical_diversity(text): #average number of times a token occurs
    return len(text)/len(set(text))

# %%
lexical_diversity(text2)
# Out:
# 20

# %%
sent1=['call','me','Ishmael']

# %%
sent1
# Out:
# ['call', 'me', 'Ishmael']

# %%
sent1.append('Please')

# %%
sent1
# Out:
# ['call', 'me', 'Ishmael', 'Please']

# %%
print sent1
# Out:
# ['call', 'me', 'Ishmael', 'Please']

# %%
fruits=['banana','apple','melon']
for fruit in fruits:
    print 'Now chopping: ', fruit
print 'Fruit Salad!'
# Out:
# Now chopping:  banana
# Now chopping:  apple
# Now chopping:  melon
# Fruit Salad!

# %%
library=[text1,text2,text3,text4,text5,text6,text7,text8,text9]

# %%
for book in library:
    print (book, lexical_diversity(book))
# Out:
# (<Text: Moby Dick by Herman Melville 1851>, 13)
# (<Text: Sense and Sensibility by Jane Austen 1811>, 20)
# (<Text: The Book of Genesis>, 16)
# (<Text: Inaugural Address Corpus>, 14)
# (<Text: Chat Corpus>, 7)
# (<Text: Monty Python and the Holy Grail>, 7)
# (<Text: Wall Street Journal>, 8)
# (<Text: Personals Corpus>, 4)
# (<Text: The Man Who Was Thursday by G . K . Chesterton 1908>, 10)

# %%
library=[text1,text2,text3,text4,text5,text6,text7,text8,text9]
for book in library:
    print (book, lexical_diversity(book))
# Out:
# (<Text: Moby Dick by Herman Melville 1851>, 13)
# (<Text: Sense and Sensibility by Jane Austen 1811>, 20)
# (<Text: The Book of Genesis>, 16)
# (<Text: Inaugural Address Corpus>, 14)
# (<Text: Chat Corpus>, 7)
# (<Text: Monty Python and the Holy Grail>, 7)
# (<Text: Wall Street Journal>, 8)
# (<Text: Personals Corpus>, 4)
# (<Text: The Man Who Was Thursday by G . K . Chesterton 1908>, 10)

# %%
print_function
# Out:
# _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 65536)

# %%
sorted(set(text3)) [25:35]
# Out:
# [u'Achbor',
#  u'Adah',
#  u'Adam',
#  u'Adbeel',
#  u'Admah',
#  u'Adullamite',
#  u'After',
#  u'Aholibamah',
#  u'Ahuzzath',
#  u'Ajah']

# %% [raw]
# print text4.index('awaken')

# %%
print ho
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-81d2756557b6> in <module>()
# ----> 1 print ho
#
# NameError: name 'ho' is not defined

# %%
print text4.index('awaken')
# Out:
# 173

# %%
print text4[158]
# Out:
# the

# %%
type(text4)
# Out:
# nltk.text.Text

# %%
print text6[12478:12556] #Unicode and ASCII text encoding
# Out:
# [u'But', u'there', u'is', u'one', u'small', u'problem', u'.', u'ARTHUR', u':', u'What', u'is', u'that', u'?', u'HEAD', u'KNIGHT', u':', u'We', u'are', u'now', u'...', u'no', u'longer', u'the', u'Knights', u'Who', u'Say', u"'", u'Ni', u"'.", u'KNIGHTS', u'OF', u'NI', u':', u'Ni', u'!', u'Shh', u'!', u'HEAD', u'KNIGHT', u':', u'Shh', u'!', u'We', u'are', u'now', u'the', u'Knights', u'Who', u'Say', u"'", u'Ecky', u'-', u'ecky', u'-', u'ecky', u'-', u'ecky', u'-', u'pikang', u'-', u'zoop', u'-', u'boing', u'-', u'goodem', u'-', u'zoo', u'-', u'owli', u'-', u'zhiv', u"'.", u'RANDOM', u':', u'Ni', u'!', u'HEAD', u'KNIGHT']

# %%
sent=['The','Quick','brown','fox']

# %%
print sent[0]
# Out:
# The

# %%
sent=['The','Quick','brown','fox']
print sent[0]
print sent[2]
# Out:
# The
# brown

# %%
sent[1]='fast'
sent[3]='cow'
print sent
# Out:
# ['The', 'fast', 'brown', 'cow']

# %%
#it was a dark and stormy night;the rain fell in torrents

# %%
opening=['it', 'was', 'a', 'dark', 'and', 'stormy', 'night',';','the', 'rain', 'fell', 'in', 'torrents']
#clause=[]
#for token in opening:
clause=opening[0:8]#slice part of vector


#clause=
alphabetise_clause=sorted(clause)

# %%
clause
# Out:
# ['it', 'was', 'a', 'dark', 'and', 'stormy', 'night', ';']

# %%
alphabetise_clause
# Out:
# [';', 'a', 'and', 'dark', 'it', 'night', 'stormy', 'was']

# %%
opening2='it' 'was' 'a' 'dark' 'and' 'stormy' 'night' ';' 'the' 'rain' 'fell' 'in' 'torrents'

# %%
opening2='it was a dark and stormy night;the rain fell in torrents'.split()

# %%
opening2
# Out:
# ['it',
#  'was',
#  'a',
#  'dark',
#  'and',
#  'stormy',
#  'night;the',
#  'rain',
#  'fell',
#  'in',
#  'torrents']

# %%
opening2[0]
# Out:
# 'it'

# %%
from nltk.probability import FreqDist
from collections import Counter

# %%
fdist1=FreqDist(text1)

# %%
fdist1.most_common(50)
# Out:
# [(u',', 18713),
#  (u'the', 13721),
#  (u'.', 6862),
#  (u'of', 6536),
#  (u'and', 6024),
#  (u'a', 4569),
#  (u'to', 4542),
#  (u';', 4072),
#  (u'in', 3916),
#  (u'that', 2982),
#  (u"'", 2684),
#  (u'-', 2552),
#  (u'his', 2459),
#  (u'it', 2209),
#  (u'I', 2124),
#  (u's', 1739),
#  (u'is', 1695),
#  (u'he', 1661),
#  (u'with', 1659),
#  (u'was', 1632),
#  (u'as', 1620),
#  (u'"', 1478),
#  (u'all', 1462),
#  (u'for', 1414),
#  (u'this', 1280),
#  (u'!', 1269),
#  (u'at', 1231),
#  (u'by', 1137),
#  (u'but', 1113),
#  (u'not', 1103),
#  (u'--', 1070),
#  (u'him', 1058),
#  (u'from', 1052),
#  (u'be', 1030),
#  (u'on', 1005),
#  (u'so', 918),
#  (u'whale', 906),
#  (u'one', 889),
#  (u'you', 841),
#  (u'had', 767),
#  (u'have', 760),
#  (u'there', 715),
#  (u'But', 705),
#  (u'or', 697),
#  (u'were', 680),
#  (u'now', 646),
#  (u'which', 640),
#  (u'?', 637),
#  (u'me', 627),
#  (u'like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist1.plot(50,cumulative=True)

# %%
#define function that will calculate most common words in each text and looping over library top 15 tokens in each text
def common_words(text,top):
    freqdist=FreqDist(text)
    #freqdist.plot()
    return freqdist.most_common(top)
    #return freqdist

# %%
for text in library:
    print text, common_words(text,15)
# Out:
# <Text: Moby Dick by Herman Melville 1851> [(u',', 18713), (u'the', 13721), (u'.', 6862), (u'of', 6536), (u'and', 6024), (u'a', 4569), (u'to', 4542), (u';', 4072), (u'in', 3916), (u'that', 2982), (u"'", 2684), (u'-', 2552), (u'his', 2459), (u'it', 2209), (u'I', 2124)]
# <Text: Sense and Sensibility by Jane Austen 1811> [(u',', 9397), (u'to', 4063), (u'.', 3975), (u'the', 3861), (u'of', 3565), (u'and', 3350), (u'her', 2436), (u'a', 2043), (u'I', 2004), (u'in', 1904), (u'was', 1846), (u'it', 1568), (u'"', 1506), (u';', 1419), (u'she', 1333)]
# <Text: The Book of Genesis> [(u',', 3681), (u'and', 2428), (u'the', 2411), (u'of', 1358), (u'.', 1315), (u'And', 1250), (u'his', 651), (u'he', 648), (u'to', 611), (u';', 605), (u'unto', 590), (u'in', 588), (u'that', 509), (u'I', 484), (u'said', 476)]
# ...

# %%
fdist2=FreqDist(len(word)for word in text1)

# %%
fdist2.max()
# Out:
# 3

# %%
fdist2
# Out:
# Counter({1: 47933,
#          2: 38513,
#          3: 50223,
#          4: 42345,
#          5: 26597,
#          6: 17111,
#          7: 14399,
#          8: 9966,
#          9: 6428,
#          10: 3528,
#          11: 1873,
#          12: 1053,
#          13: 567,
#          14: 177,
#          15: 70,
#          16: 22,
#          17: 12,
#          18: 1,
#          20: 1})

# %%
vocab=set(text4)
long_words=[word for word in vocab if len(word)>15]
sorted(long_words)
# Out:
# [u'RESPONSIBILITIES',
#  u'antiphilosophists',
#  u'constitutionally',
#  u'contradistinction',
#  u'discountenancing',
#  u'disqualification',
#  u'enthusiastically',
#  u'instrumentalities',
#  u'internationality',
#  u'irresponsibility',
#  u'misappropriation',
#  u'misrepresentation',
#  u'misunderstanding',
#  u'responsibilities',
#  u'sentimentalizing',
#  u'transcontinental',
#  u'uncharitableness',
#  u'unconstitutional']

# %%
sent1
# Out:
# ['call', 'me', 'Ishmael', 'Please']

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
sent4
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
for word in sent4:
    
    if len(word)>4:
        print 'More than Four==>',word
    if len(word)==4:
        print 'Exactly Four==>',word
    if len(word)>=4:     
        print 'Four or more==>',word
# Out:
# More than Four==> Fellow
# Four or more==> Fellow
# More than Four==> Citizens
# Four or more==> Citizens
# More than Four==> Senate
# Four or more==> Senate
# More than Four==> House
# Four or more==> House
# More than Four==> Representatives
# Four or more==> Representatives

# %%
vocab=set(sent4)
long_words=[word for word in vocab if len(word)>4 ]
sorted(long_words)
# Out:
# ['Citizens', 'Fellow', 'House', 'Representatives', 'Senate']

# %%
fdist5=FreqDist(text5)

# %%
fdist5.freq
# Out:
# <bound method FreqDist.freq of FreqDist({u'.': 1268, u'JOIN': 1021, u'PART': 1016, u'?': 737, u'lol': 704, u'to': 658, u'i': 648, u'the': 646, u'you': 635, u',': 596, ...})>

# %%
words=set(text5) #No duplicates
for word in words:
    if len(word)>7 and fdist5[word]>7:
        print word
# Out:
# innocent
# seriously
# #14-19teens
# anything
# together
# remember
# tomorrow
# listening
# actually
# ........
# Question
# computer
# everyone
# ((((((((((
# #talkcity_adults
# football
# something
# cute.-ass
# watching

# %%
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
# Out:
# [u'#14-19teens',
#  u'#talkcity_adults',
#  u'((((((((((',
#  u'........',
#  u'Question',
#  u'actually',
#  u'anything',
#  u'computer',
#  u'cute.-ass',
#  u'everyone',
#  u'football',
#  u'innocent',
#  u'listening',
#  u'remember',
#  u'seriously',
#  u'something',
#  u'together',
#  u'tomorrow',
#  u'watching']

# %%
sorted(number for number in sent7 if number.isdigit())
# Out:
# ['29', '61']

# %%
len(set(text1))
# Out:
# 19317

# %%
len(set(word.lower() for word in text1))
# Out:
# 17231

# %%
len(set(word.lower() for word in text1 if word.isalpha()))
# Out:
# 16948

# %%
# !ls
# Out:
# Andres-NLTK.ipynb	UMA_Fraser_Radio_Talks.zip
# UMA_Fraser_Radio_Talks	nltk_data

# %%
# !cd UMA_Fraser_Radio_Talks/

# %%
# !ls
# Out:
# Andres-NLTK.ipynb	UMA_Fraser_Radio_Talks.zip
# UMA_Fraser_Radio_Talks	nltk_data
